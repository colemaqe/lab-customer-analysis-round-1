# %%
import pandas as pd

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1_list = list(file1)
file1_list
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
file2_list = list(file2)
file1_list
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
file3_list = list(file3)
file3_list
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %%
file1 = file1.rename(columns={'ST' : 'State' , 'GENDER' : 'Gender'})

# %%
file2 = file2.rename(columns={'ST' : 'State' , 'GENDER' : 'Gender'})

# %%
file1_reorder = file1[['Customer',
 'State',
 'Customer Lifetime Value',
 'Education',
 'Gender',
 'Income',
 'Monthly Premium Auto',
 'Number of Open Complaints',
 'Policy Type',
 'Total Claim Amount',
 'Vehicle Class']]

# %%
list(file1_reorder)
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %%
file2_reorder = file2[['Customer',
 'State',
 'Customer Lifetime Value',
 'Education',
 'Gender',
 'Income',
 'Monthly Premium Auto',
 'Number of Open Complaints',
 'Policy Type',
 'Total Claim Amount',
 'Vehicle Class']]

# %%
list(file2_reorder)
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Education',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %%
data = pd.concat([file1_reorder,file2_reorder,file3])
data
# Out:
#      Customer       State Customer Lifetime Value             Education  \
# 0     RB50392  Washington                     NaN                Master
# 1     QZ44356     Arizona              697953.59%              Bachelor
# 2     AI49188      Nevada             1288743.17%              Bachelor
# 3     WW63253  California              764586.18%              Bachelor
# 4     GA49547  Washington              536307.65%  High School or Below
# ...       ...         ...                     ...                   ...
# 7065  LA72316  California             23405.98798              Bachelor
# 7066  PK87824  California             3096.511217               College
# 7067  TD14365  California             8163.890428              Bachelor
# 7068  UP19263  California             7524.442436               College
# 7069  Y167826  California             2611.836866               College
#
#      Gender   Income  Monthly Premium Auto Number of Open Complaints  \
# ...

# %%
data.dtypes
# Out:
# Customer                      object
# State                         object
# Customer Lifetime Value       object
# Education                     object
# Gender                        object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
data2 = data.drop("Education", axis='columns')

# %%
data3 = data2.drop("Number of Open Complaints", axis='columns')

# %%
list(data3)
# Out:
# ['Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Gender',
#  'Income',
#  'Monthly Premium Auto',
#  'Policy Type',
#  'Total Claim Amount',
#  'Vehicle Class']

# %%
data3
# Out:
#      Customer       State  Customer Lifetime Value Gender   Income  \
# 0     RB50392  Washington                      NaN    NaN      0.0
# 1     QZ44356     Arizona                      NaN      F      0.0
# 2     AI49188      Nevada                      NaN      F  48767.0
# 3     WW63253  California                      NaN      M      0.0
# 4     GA49547  Washington                      NaN      M  36357.0
# ...       ...         ...                      ...    ...      ...
# 7065  LA72316  California             2.340599e+06      M  71941.0
# 7066  PK87824  California             3.096511e+05      F  21604.0
# 7067  TD14365  California             8.163890e+05      M      0.0
# 7068  UP19263  California             7.524442e+05      M  21941.0
# 7069  Y167826  California             2.611837e+05      M      0.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
data3["Customer Lifetime Value"] = 100000 * data3["Customer Lifetime Value"]

# %%
data3
# Out:
#      Customer       State  Customer Lifetime Value Gender   Income  \
# 0     RB50392  Washington                      NaN    NaN      0.0
# 1     QZ44356     Arizona                      NaN      F      0.0
# 2     AI49188      Nevada                      NaN      F  48767.0
# 3     WW63253  California                      NaN      M      0.0
# 4     GA49547  Washington                      NaN      M  36357.0
# ...       ...         ...                      ...    ...      ...
# 7065  LA72316  California             2.340599e+11      M  71941.0
# 7066  PK87824  California             3.096511e+10      F  21604.0
# 7067  TD14365  California             8.163890e+10      M      0.0
# 7068  UP19263  California             7.524442e+10      M  21941.0
# 7069  Y167826  California             2.611837e+10      M      0.0
#
#       Monthly Premium Auto     Policy Type  Total Claim Amount  Vehicle Class
# 0                   1000.0   Personal Auto            2.704934  Four-Door Car
# ...

# %%
data3.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       Customer  State  Customer Lifetime Value  Gender  Income  \
# 0        False  False                     True    True   False
# 1        False  False                     True   False   False
# 2        False  False                     True   False   False
# 3        False  False                     True   False   False
# 4        False  False                     True   False   False
# ...        ...    ...                      ...     ...     ...
# 7065     False  False                    False   False   False
# 7066     False  False                    False   False   False
# 7067     False  False                    False   False   False
# 7068     False  False                    False   False   False
# 7069     False  False                    False   False   False
#
#       Monthly Premium Auto  Policy Type  Total Claim Amount  Vehicle Class
# ...

# %%
round(data3.isna().sum()/len(data3),4)*100  # shows the percentage of null values in a column
nulls_df = pd.DataFrame(round(data3.isna().sum()/len(data3),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                header_name  percent_nulls
# 0                 Customer          24.32
# 1                    State          24.32
# 2  Customer Lifetime Value          41.44
# 3                   Gender          25.34
# 4                   Income          24.32
# 5     Monthly Premium Auto          24.32
# 6              Policy Type          24.32
# 7       Total Claim Amount          24.32
# 8            Vehicle Class          24.32

# %%
data3.isna().sum()
# Out:
# Customer                   2937
# State                      2937
# Customer Lifetime Value    5004
# Gender                     3059
# Income                     2937
# Monthly Premium Auto       2937
# Policy Type                2937
# Total Claim Amount         2937
# Vehicle Class              2937
# dtype: int64
